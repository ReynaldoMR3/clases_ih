# %% [markdown]
# <a href="https://colab.research.google.com/github/ReynaldoMR3/clases_ih/blob/main/KATA_MATPLOTLIB_SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib Exercises**
#
#
# Time to practice your new matplotlib skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ReynaldoMR3/clases_ih/main/company_sales_data.csv")

# %%
df.head()
# Out:
#    month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0             1       2500      1500  ...         1500        21100        211000
# 1             2       2630      1200  ...         1200        18330        183300
# 2             3       2140      1340  ...         1340        22470        224700
# 3             4       3400      1130  ...         1130        22270        222700
# 4             5       3600      1740  ...         1740        20960        209600
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Exercises
#
# Recreate the plots below using the dataframe in the variable df. Keep careful attention to the x and y labels for hints.

# %% [markdown]
# Exercise 1: Read Total profit of all months and show it using a line plot
#
# ![image.png](data:image/png;base64,...)

# %%
#Your code here

# %% [markdown]
# Exercise 2: Get Total profit of all months and show line plot
#
#
# Bonus!!! Plot with the same style properties
#
#
# ![image.png](data:image/png;base64,...)

# %%
# your code here

# %% [markdown]
# Exercise 3: Read toothpaste sales data of each month and show it using a scatter plot
#
#
# ![image.png](data:image/png;base64,...)

# %%
# your code here

# %% [markdown]
# Exercise 4: Read face cream and facewash product sales data and show it using the bar chart
#
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here

# %% [markdown]
# Exercise 6: Calculate total sale data for last year for each product and show it using a Pie chart
#
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here

# %% [markdown]
# # **Seaborn Exercises**
#
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# ## **Exercises**
#
# Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.

# %% [markdown]
# Exercise 1.
#
# ![image.png](data:image/png;base64,...)

# %%
# your code here

# %% [markdown]
# Exercise 2.
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here

# %% [markdown]
# Exercise 3.
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here

# %% [markdown]
# Exercise 4.
#
# ![image.png](data:image/png;base64,...)

# %%
# your code here

# %% [markdown]
# Exercise 5
#
#
# ![image.png](data:image/png;base64,...)

# %%
# your code here

# %% [markdown]
# Exercise 6
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here

# %% [markdown]
# Exercise 7
#
# ![image.png](data:image/png;base64,...)

# %%
#your code here
